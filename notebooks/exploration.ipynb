# %%
# !pip install reportlab
# !pip install svglib
# Out:
# Requirement already satisfied: reportlab in /opt/anaconda3/lib/python3.11/site-packages (4.4.3)
# Requirement already satisfied: pillow>=9.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from reportlab) (10.2.0)
# Requirement already satisfied: charset-normalizer in /opt/anaconda3/lib/python3.11/site-packages (from reportlab) (3.3.2)
# Requirement already satisfied: svglib in /opt/anaconda3/lib/python3.11/site-packages (1.5.1)
# Requirement already satisfied: reportlab in /opt/anaconda3/lib/python3.11/site-packages (from svglib) (4.4.3)
# Requirement already satisfied: lxml in /opt/anaconda3/lib/python3.11/site-packages (from svglib) (5.2.2)
# Requirement already satisfied: tinycss2>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from svglib) (1.3.0)
# Requirement already satisfied: cssselect2>=0.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from svglib) (0.8.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.11/site-packages (from cssselect2>=0.2.0->svglib) (0.5.1)
# Requirement already satisfied: pillow>=9.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from reportlab->svglib) (10.2.0)
# Requirement already satisfied: charset-normalizer in /opt/anaconda3/lib/python3.11/site-packages (from reportlab->svglib) (3.3.2)

# %%
import pandas as pd

from reportlab.lib.pagesizes import LETTER
from reportlab.pdfgen import canvas
from reportlab.lib.colors import black, HexColor, white, grey
from reportlab.graphics import renderPDF

# %%
# goal: generate PDF files pre-filled with information. Write a script to do all of the conditional formatting for 
# each attendee's badge and render it into a PDF document. This would be things like filling in their name, 
# company, pronouns, photo release indication, etc... based on a CSV dump of the data from the ticketing provider

# %%
df = pd.read_csv("tito-export-format.csv")
df.head()
# Out:
#    Number                 Ticket        Ticket Company Name  \
# 0     116   Early Bird Corporate  The Aerospace Corporation
# 1     117  Early Bird Individual                        NaN
# 2     118  Early Bird Individual                        NaN
# 3     119  Early Bird Individual                    Caltech
# 4     120      Donate to PyBeach                    Caltech
#
#                Ticket Job Title Photo opt-out        Pronouns  \
# 0                Project Leader       Opt-out  He / Him / His
# 1                           NaN        Opt-in          He/him
# 2         Sr. Software Engineer        Opt-in          He/Him
# 3  Senior Application Developer        Opt-in         She/Her
# 4  Senior Application Developer           NaN             NaN
#
#   What name would you like printed on your badge?  \
# 0                                           Henry
# 1                                     Albert Chae
# 2                                  Austin Simmons
# 3                                   Cynthia Kiser
# 4                                             NaN
#
#    Would you like your pronouns printed on your badge?
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df.columns
# Out:
# Index(['Number', 'Ticket', 'Ticket Company Name', 'Ticket Job Title',
#        'Photo opt-out', 'Pronouns',
#        'What name would you like printed on your badge?',
#        'Would you like your pronouns printed on your badge?'],
#       dtype='object')

# %%
df['Ticket'].unique()
# Out:
# array(['Early Bird Corporate', 'Early Bird Individual',
#        'Donate to PyBeach', 'Early Bird Student', 'Individual', 'Student',
#        'Unemployed', 'Corporate'], dtype=object)

# %%
# ignore ticket type = Donate to PyBeach, which are donations
df_filtered = df[df['Ticket'] != 'Donate to PyBeach']

# %%
df_filtered['Photo opt-out'].unique()
# Out:
# array(['Opt-out', 'Opt-in', nan], dtype=object)

# %%
# ignore df rows where photo opt-out is null
df_filtered = df[df['Photo opt-out'].notna()]

# %%
# reset index
df_filtered = df_filtered.reset_index()

# %%
df_filtered['Number'].unique()
# Out:
# array([116, 117, 118, 119, 121, 122, 123, 125, 126, 127, 128, 129, 130,
#         19, 135, 137, 139, 141,  28, 144, 146, 147, 149, 150, 151, 152,
#        153, 155, 156, 157,  43, 161, 162, 163,  47,  48, 166, 167,  51,
#         53,  54, 173])

# %%
df_filtered['Photo opt-out'].unique()
# Out:
# array(['Opt-out', 'Opt-in'], dtype=object)

# %%
df_filtered['Attendee'] = 'Attendee'
df_filtered
# Out:
#     index  Number                 Ticket                 Ticket Company Name  \
# 0       0     116   Early Bird Corporate           The Aerospace Corporation
# 1       1     117  Early Bird Individual                                 NaN
# 2       2     118  Early Bird Individual                                 NaN
# 3       3     119  Early Bird Individual                             Caltech
# 4       5     121  Early Bird Individual                                 NaN
# 5       6     122     Early Bird Student                                 NaN
# 6       7     123  Early Bird Individual                      Rouse Services
# 7       9     125  Early Bird Individual                        SoCal Python
# 8      10     126  Early Bird Individual                         Flawless AI
# 9      11     127  Early Bird Individual                           8th Light
# 10     12     128     Early Bird Student                             Caltech
# 11     13     129     Early Bird Student                             Caltech
# 12     14     130   Early Bird Corporate                              Google
# 13     18      19     Early Bird Student                                 NaN
# 14     19     135  Early Bird Individual                                 NaN
# 15     21     137  Early Bird Individual                 Insulet Corporation
# 16     23     139  Early Bird Individual                     UC OSPO Network
# 17     25     141  Early Bird Individual                                 NaN
# 18     27      28  Early Bird Individual                                 NaN
# 19     28     144  Early Bird Individual                     Kora Frameworks
# 20     30     146  Early Bird Individual                                 NaN
# 21     31     147  Early Bird Individual                                 NaN
# 22     33     149  Early Bird Individual                                 NaN
# 23     34     150  Early Bird Individual                                 NaN
# 24     35     151  Early Bird Individual                             Duetti
# 25     36     152  Early Bird Individual                      Python Morsels
# 26     37     153  Early Bird Individual                                 NaN
# 27     39     155     Early Bird Student                                 NaN
# 28     40     156             Individual                             Caltech
# 29     41     157                Student  N/A:  Current Cornell Grad Student
# 30     42      43                Student                                 USC
# 31     43     161             Unemployed                                 NaN
# 32     44     162             Individual                     Click Analytics
# 33     45     163              Corporate                           8th Light
# 34     46      47              Corporate                                Meta
# 35     47      48             Individual                 Websperts Institute
# 36     48     166                Student                                 NaN
# 37     49     167              Corporate                 Research Affiliates
# 38     50      51             Individual            SETI Institute/NASA Ames
# 39     52      53              Corporate                                Meta
# 40     53      54              Corporate                                Meta
# 41     55     173             Unemployed                     Genial Labs LLC
#
#                             Ticket Job Title Photo opt-out        Pronouns  \
# 0                             Project Leader       Opt-out  He / Him / His
# 1                                        NaN        Opt-in          He/him
# 2                      Sr. Software Engineer        Opt-in          He/Him
# 3               Senior Application Developer        Opt-in         She/Her
# 4                                        NaN        Opt-in        He / Him
# 5                                        NaN        Opt-in        He / Him
# 6           Director of Cloud Infrastructure        Opt-in        He / Him
# 7                                  Organizer       Opt-out         she/her
# 8                    Staff Platform Engineer        Opt-in        He / Him
# 9                                    Crafter        Opt-in        he / him
# 10                                  Research       Opt-out        He / Him
# 11                                       NaN       Opt-out       She / Her
# 12                         Software Engineer        Opt-in               -
# 13                                       NaN        Opt-in         She/Her
# 14                                       NaN        Opt-in          He/Him
# 15                      Senior Test Engineer        Opt-in          He/Him
# 16                         Community Manager        Opt-in         She/her
# 17                                       NaN        Opt-in         he/they
# 18                                       NaN        Opt-in         She/Her
# 19                        Software Developer        Opt-in          He/Him
# 20                                       NaN        Opt-in         She/Her
# 21                                       NaN        Opt-in              He
# 22                                       NaN        Opt-in      he/him/his
# 23                                       NaN        Opt-in        He / Him
# 24                             Data Engineer        Opt-in         She/Her
# 25                            Python Teacher        Opt-in        He / Him
# 26                                       NaN        Opt-in       She / Her
# 27                                       NaN       Opt-out          He/him
# 28         Senior Research Software Engineer        Opt-in        he / him
# 29                      Cornell Grad Student        Opt-in             she
# 30                                   Student        Opt-in         She/Her
# 31                                       NaN        Opt-in        He / Him
# 32                                       CEO        Opt-in          he/him
# 33                        Principal Engineer        Opt-in          He/him
# 34                         Software Engineer        Opt-in         She/Her
# 35  Data/AI/ML Scientist/Engineer/Researcher        Opt-in          He/Him
# 36                                       NaN        Opt-in        He / Him
# 37                                       CTO        Opt-in        He / Him
# 38           Senior Science Systems Engineer       Opt-out          He/Him
# 39                Python Foundation Engineer        Opt-in       She / Her
# 40                        Developer Advocate        Opt-in       She / Her
# 41                                Consultant        Opt-in          He/Him
#
#       What name would you like printed on your badge?  \
# 0                                               Henry
# 1                                         Albert Chae
# 2                                      Austin Simmons
# 3                                       Cynthia Kiser
# 4                                   Victor Hugo Solis
# 5                                      Bolun Thompson
# 6                                        Andrew Kurin
# 7                                              Esther
# 8                                              Dorian
# 9                                               Ian G
# 10                                   Michael Langmayr
# 11                                           Prakriti
# 12                                      Brett Slatkin
# 13                                             Shikha
# 14                                         Ryan Hamel
# 15                                     Jorge L Gimeno
# 16                                      Laura Langdon
# 17                                         David Lord
# 18                                           Charón G
# 19                                          Ben Patch
# 20                                             Maya Z
# 21                                               Gabe
# 22                                         Nik Kantar
# 23                                       Rick Randall
# 24                                       Sophia Alice
# 25                                        Trey Hunner
# 26                                      Melanie Arbor
# 27                                               Tony
# 28                                       Pete Bachant
# 29                                        Mad Chemist
# 30                                         Akarsha :)
# 31                                      Kushal Sharma
# 32                                              Bobby
# 33                                       Jeff Ramnani
# 34                                       Rebecca Chen
# 35  Foad        Data/AI/ML Scientist/Engineer/Rese...
# 36                                              Jacob
# 37                                        Chris Ariza
# 38                                 Andrew Annex, PhD.
# 39                                        Parul Gupta
# 40                                      Abby Mitchell
# 41                                      Dr Ravi Kalia
#
#     Would you like your pronouns printed on your badge?  Attendee
# 0                                                 NaN    Attendee
# 1                                                 NaN    Attendee
# 2                                                 NaN    Attendee
# 3                                                 NaN    Attendee
# 4                                                 NaN    Attendee
# 5                                                 NaN    Attendee
# 6                                                 NaN    Attendee
# 7                                                 NaN    Attendee
# 8                                                 NaN    Attendee
# 9                                                 NaN    Attendee
# 10                                                NaN    Attendee
# 11                                                NaN    Attendee
# 12                                                NaN    Attendee
# 13                                                NaN    Attendee
# 14                                                NaN    Attendee
# 15                                                NaN    Attendee
# 16                                                NaN    Attendee
# 17                                                NaN    Attendee
# 18                                                NaN    Attendee
# 19                                                NaN    Attendee
# 20                                                NaN    Attendee
# 21                                                NaN    Attendee
# 22                                                NaN    Attendee
# 23                                                NaN    Attendee
# 24                                                NaN    Attendee
# 25                                                NaN    Attendee
# 26                                                NaN    Attendee
# 27                                                NaN    Attendee
# 28                                                NaN    Attendee
# 29                                                NaN    Attendee
# 30                                                NaN    Attendee
# 31                                                NaN    Attendee
# 32                                                NaN    Attendee
# 33                                                NaN    Attendee
# 34                                                NaN    Attendee
# 35                                                NaN    Attendee
# 36                                                NaN    Attendee
# 37                                                NaN    Attendee
# 38                                                NaN    Attendee
# 39                                                NaN    Attendee
# 40                                                NaN    Attendee
# 41                                                NaN    Attendee

# %%
def return_fontsize_that_fits(badge_width, text, font_size):
    text_width = stringWidth(text, 'Helvetica', font_size)
    while text_width > badge_width:
        font_size -= 3
        text_width = stringWidth(text, 'Helvetica', font_size)
    return font_size

def standardize_pronouns(pronoun_str):
    if "/" in pronoun_str:
        pronouns = pronoun_str.split("/")
    else:
        pronouns = [pronoun_str]

    pronouns = [pro.lower().strip() for pro in pronouns]
    final_list = []
    
    if 'he' in pronouns or 'him' in pronouns or 'his' in pronouns:
        final_list.append('he')
    if 'she' in pronouns or 'her' in pronouns or 'hers' in pronouns:
        final_list.append('she')
    if 'they' in pronouns or 'them' in pronouns or 'theirs' in pronouns or 'their' in pronouns:
        final_list.append('they')

    # only she:
    if len(final_list) == 1:
        if final_list[0] == 'he':
            return 'He / Him'
        elif final_list[0] == 'she':
            return 'She / Hers'
        else:
            return 'They / Them'
    else:
        final = ""
        for item in final_list:
            final += item.capitalize() + " / "
        return final[:-2]
    
def format_pronouns(pronoun_str):
    cleaned = " ".join(pronoun_str.split())
    cleaned = re.sub(r"\s*/\s*", " / ", cleaned)
    formatted = " ".join(word.capitalize() for word in cleaned.split())
    return formatted

# %%
standardize_pronouns('He / him')
# Out:
# 'He / Him'

# %%
from svglib.svglib import svg2rlg

badge_count = 0
badge_width = 4 * 72    # 2 inches
badge_height = 2.875 * 72   # 3 inches
width, height = LETTER
# 10 point margin on sides, 20 point on top bottom
badge_xys = [
    (10, 565),   # top left
    (316, 565), # top right
    (10, 338),   # middle left
    (316, 338), # middle right
    (10, 111),   # bottom left
    (316, 111)  # bottom right
]

# starting canvas
output_path = "badges_0.pdf"
c = canvas.Canvas(output_path, pagesize=LETTER)

for index, row in df_filtered.iterrows():
    if badge_count == 6:
        c.save()
        print(f"PDF saved to {output_path}")
        output_path = "badges_" + str(index) + ".pdf"
        # start a new sheet of badges
        c = canvas.Canvas(output_path, pagesize=LETTER)
        c.setFillColor(black)
        badge_count = 0
    name = row["What name would you like printed on your badge?"]
    if pd.isna(name):
        print(f'Error with row {index}: name is empty')
        continue
    if pd.isna(row['Number']):
        print(f'Error with row {index}: number is empty')
        continue
    
    # top left for the badge
    # 20 point margins
    x = badge_xys[badge_count][0]
    y = badge_xys[badge_count][1]
    
    # photo opt-out icon: top left
    if row['Photo opt-out'] == 'Opt-out':
        # c.drawImage('camera.png', x + 4, y + badge_height - 50, width=50, height=50, mask='auto')
        drawing = svg2rlg('no-photos.svg')
        logo_size = 50
        scale = min(logo_size / drawing.width, logo_size / drawing.height)
        drawing.width *= scale
        drawing.height *= scale
        drawing.scale(scale, scale)
        renderPDF.draw(drawing, c, x + 4, y + badge_height - 50)
    
    # pronouns: top right
    pronouns_option = row['Would you like your pronouns printed on your badge?']
    if pd.isna(pronouns_option) or pronouns_option == 'Yes':
        pronouns = row['Pronouns']
        # could be None
        if not pd.isna(pronouns) and pronouns != "-":
            c.setFont("Helvetica", 13)
            c.setFillColor(black)
            c.drawRightString(x + badge_width - 4, y + badge_height - 8, pronouns)

    drawing = svg2rlg('pybeach2025-fullcolor.svg')
    logo_size = 72
    scale = min(logo_size / drawing.width, logo_size / drawing.height)
    drawing.width *= scale
    drawing.height *= scale
    drawing.scale(scale, scale)

    renderPDF.draw(drawing, c, x + (badge_width - logo_size) / 2, y + badge_height - logo_size - 10)
    # name: center
    # clean up spacing in name
    cleaned_name = re.sub(r"\s+", " ", name).strip()
    font_size = return_fontsize_that_fits(badge_width, cleaned_name, 20)
    c.setFont("Helvetica-Bold", font_size)
    c.setFillColor(black)
    # c.drawCentredString(x + badge_width / 2, ((y + badge_height - logo_size - 10) + 130) / 2, cleaned_name)

    # Company name should only be printed on Corporate and Early Bird Corporate badges
    # options: nothing, just company, just title, or both
    typ = row["Ticket"]
    company = ""
    if typ == 'Early Bird Corporate' or typ == 'Corporate':
        company_name = row["Ticket Company Name"]
        company = company_name
        if not pd.isna(row["Ticket Job Title"]):
            title = row["Ticket Job Title"]
            company = f"{title}, " + company
    else:
        if not pd.isna(row["Ticket Job Title"]):
            title = row["Ticket Job Title"]
            company = f"{title} " + company

    if company == "":
        name_y = y + badge_height - 125
    else:
        name_y = y + badge_height - 110
        # else: empty line
    
    cleaned_name = re.sub(r"\s+", " ", name).strip()
    font_size = return_fontsize_that_fits(badge_width, cleaned_name, 20)
    c.setFont("Helvetica-Bold", font_size)
    c.setFillColor(black)
    c.drawCentredString(x + badge_width / 2, name_y, cleaned_name)

    if company != "":
        job_font_size = return_fontsize_that_fits(badge_width, company, 14)
        c.setFont("Helvetica", job_font_size)
        c.setFillColor(black)
        c.drawCentredString(x + badge_width / 2, y + badge_height - 130, company)

    
    

    #     job_title = row["Ticket Job Title"]
    # if not pd.isna(job_title):
    #     line = line - 20
    #     c.drawString(100, line, f"Job Title: {job_title}")
    event = 'PyBeach | September 27, 2025' 
    c.setFillColor(grey)
    c.setFont("Helvetica", 13)
    c.drawCentredString(x + badge_width / 2, y + badge_height - 165, event)

    if not pd.isna(row["Attendee"]):
        ribbon_height = 25
        c.setFillColor(HexColor("#337ab7"))
        c.rect(x, y + 5, badge_width, ribbon_height, stroke=0, fill=1)
        c.setFillColor(white)
        c.setFont("Helvetica-Bold", 14)
        c.drawCentredString(x + badge_width / 2, y + 12, row["Attendee"])
    else:
        print(f'Warning: {name} does not have a value for Attendee column.')
    
    badge_count += 1
# save any remaining canvas
c.save()
print(f"PDF saved to {output_path}")
# Out:
# PDF saved to badges_0.pdf
# PDF saved to badges_6.pdf
# PDF saved to badges_12.pdf
# PDF saved to badges_18.pdf
# PDF saved to badges_24.pdf
# PDF saved to badges_30.pdf
# PDF saved to badges_36.pdf

# %%
df_filtered[df_filtered['Photo opt-out'] == 'Opt-out']
# Out:
#     index  Number                 Ticket        Ticket Company Name  \
# 0       0     116   Early Bird Corporate  The Aerospace Corporation
# 7       9     125  Early Bird Individual               SoCal Python
# 10     12     128     Early Bird Student                    Caltech
# 11     13     129     Early Bird Student                    Caltech
# 27     39     155     Early Bird Student                        NaN
# 38     50      51             Individual   SETI Institute/NASA Ames
#
#                    Ticket Job Title Photo opt-out        Pronouns  \
# 0                    Project Leader       Opt-out  He / Him / His
# 7                         Organizer       Opt-out         she/her
# 10                         Research       Opt-out        He / Him
# 11                              NaN       Opt-out       She / Her
# 27                              NaN       Opt-out          He/him
# 38  Senior Science Systems Engineer       Opt-out          He/Him
#
#    What name would you like printed on your badge?  \
# 0                                            Henry
# 7                                           Esther
# 10                                Michael Langmayr
# 11                                        Prakriti
# 27                                            Tony
# 38                              Andrew Annex, PhD.
#
#     Would you like your pronouns printed on your badge?
# 0                                                 NaN
# 7                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 27                                                NaN
# 38                                                NaN
